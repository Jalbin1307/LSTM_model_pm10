# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import csv
from ast import literal_eval
import pandas as pd

# %%
data = pd.read_csv("dt_v.csv", sep=",")
data.head(5)
# Out:
#    type 0  type 1  type 2  type 3  type 4  type 5  type 6  type 7  type 8  \
# 0       4       8       9       3      23      24      14       2       9
# 1       4       8      12       3       4      34      19      14       5
# 2       5      14      33       4      17      47       3       3      33
# 3       4      16       9       3      13      59       6       2      19
# 4       5      23      27       3      13      48      17       1       6
#
#    type 9  ...  type 90  type 91  type 92  type 93  type 94  type 95  type 96  \
# 0      39  ...        2        2        2        6       10       19       26
# 1      24  ...        2        2        2        7       10        2       37
# 2      29  ...        7        7        2        8       19       20       46
# 3      37  ...       10       10       10        6        9       17       58
# 4      36  ...        7        4       11       15       21       18       47
#
#    type 97  type 98  type 99
# ...

# %%
data.shape[1]
# Out:
# 100

# %%
type = ["type %d"%i for i in range(data.shape[1])]

# %%
data.iloc[-1]
# Out:
# type 0     233
# type 1      82
# type 2      82
# type 3      78
# type 4     160
#           ...
# type 95    160
# type 96     59
# type 97    243
# type 98    138
# type 99    137
# Name: 39, Length: 100, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scale_cols = type
df_scaled = scaler.fit_transform(data[scale_cols])

df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

print(df_scaled)
# Out:
#       type 0    type 1    type 2    type 3    type 4    type 5    type 6  \
# 0   0.004348  0.000000  0.000000  0.013158  0.127389  0.053333  0.270833
# 1   0.004348  0.000000  0.041096  0.013158  0.006369  0.186667  0.375000
# 2   0.008696  0.081081  0.328767  0.026316  0.089172  0.360000  0.041667
# 3   0.004348  0.108108  0.000000  0.013158  0.063694  0.520000  0.104167
# 4   0.008696  0.202703  0.246575  0.013158  0.063694  0.373333  0.333333
# 5   0.004348  0.202703  0.164384  0.013158  0.140127  0.546667  0.000000
# 6   0.004348  0.459459  0.000000  0.026316  0.012739  0.040000  0.041667
# 7   0.017391  0.229730  0.054795  0.065789  0.019108  0.213333  0.041667
# 8   0.034783  0.486486  0.041096  0.105263  0.082803  0.253333  0.083333
# 9   0.004348  0.175676  0.150685  0.171053  0.101911  0.453333  0.562500
# 10  0.000000  0.013514  0.027397  0.026316  0.203822  0.573333  0.354167
# 11  0.034783  0.229730  0.315068  0.105263  0.082803  0.013333  0.062500
# ...

# %%
train = df_scaled[:]
test = df_scaled[:]

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
def make_dataset(data, label, window_size = 39):
    feature_list = []
    label_list = []
    i = 0
    for t in type:
        for i in range(len(data)-window_size):
            feature_list.append(np.array(data[t].iloc[i:i+window_size]))
            label_list.append(np.array(label[t].iloc[i+window_size]))
       
    return np.array(feature_list), np.array(label_list)

# %%
feature_cols = type
#label_cols = ['type 39']

train_feature = train[feature_cols]
train_label = train[feature_cols].iloc[-1]

train_feature, train_label = make_dataset(train_feature, train_label)

from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

# x_train.shape, x_valid.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-b1070583cd0f> in <module>
#       5 train_label = train[feature_cols].iloc[-1]
#       6
# ----> 7 train_feature, train_label = make_dataset(train_feature, train_label)
#       8
#       9 from sklearn.model_selection import train_test_split
#
# <ipython-input-73-c5cd76b4cb06> in make_dataset(data, label, window_size)
#       6         for i in range(len(data)-window_size):
#       7             feature_list.append(np.array(data[t].iloc[i:i+window_size]))
# ----> 8             label_list.append(np.array(label[t].iloc[i+window_size]))
#       9
#      10     return np.array(feature_list), np.array(label_list)
#
# AttributeError: 'numpy.float64' object has no attribute 'iloc'
